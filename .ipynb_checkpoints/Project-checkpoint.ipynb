# %%
import pandas as pd
pd.set_option('display.max_rows', 1000)

# %%
path='data.csv'

# %%
health_df=pd.read_csv(path)

# %%
ind_str = health_df['Indicator Name'].unique()[70]

# %%
health_df[health_df['Indicator Name'] == ind_str]
# Out:
#                                             Country Name Country Code  \
# 70                                            Arab World          ARB
# 415                               Caribbean small states          CSS
# 760                       Central Europe and the Baltics          CEB
# 1105                          Early-demographic dividend          EAR
# 1450                                 East Asia & Pacific          EAS
# 1795         East Asia & Pacific (excluding high income)          EAP
# 2140          East Asia & Pacific (IDA & IBRD countries)          TEA
# 2485                                           Euro area          EMU
# 2830                               Europe & Central Asia          ECS
# 3175       Europe & Central Asia (excluding high income)          ECA
# 3520        Europe & Central Asia (IDA & IBRD countries)          TEC
# 3865                                      European Union          EUU
# ...

# %%
df_w_data = health_df[health_df['2009'].notnull()]

# %%
df_w_data['Indicator Name'].value_counts()
# Out:
# Population growth (annual %)                                                                                             258
# Population, total                                                                                                        258
# Rural population                                                                                                         256
# Urban population growth (annual %)                                                                                       256
# Urban population (% of total)                                                                                            256
# Urban population                                                                                                         256
# Rural population (% of total population)                                                                                 256
# ...

# %% [markdown]
# health_df.drop(health_df.iloc[:, 1:50], inplace=True, axis=1)

# %%
health_df.drop(health_df.iloc[:, 1:50], inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/b4/38_fskw17mn0l7stnl4_z2d00000gn/T/ipykernel_6957/2469526203.py in <module>
# ----> 1 health_df.drop(health_df.iloc[:, 1:50], inplace=True, axis=1)
#
# AttributeError: 'NoneType' object has no attribute 'drop'
